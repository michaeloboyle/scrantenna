# %%
import os
import json
import spacy
import re
from datetime import datetime

# Load the SpaCy NLP model
nlp = spacy.load("en_core_web_sm")

# Define directories and ensure they exist
DATA_DIR = os.path.join(os.getcwd(), 'data/raw')
GRAPH_DIR = os.path.join(os.getcwd(), 'data/graph')

# Ensure the directory for graph data exists
os.makedirs(GRAPH_DIR, exist_ok=True)

# Check current working directory for debugging
print("Current working directory:", os.getcwd())

# Load raw news data
news_files = [f for f in os.listdir(DATA_DIR) if f.endswith('.json')]

# Process news articles
articles = []
for file in news_files:
    with open(os.path.join(DATA_DIR, file), 'r') as f:
        articles.extend(json.load(f))

# Function to extract entities and events from articles
def extract_entities_and_events(article):
    doc = nlp(article['content'])
    entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['PERSON', 'ORG', 'GPE', 'DATE']]
    events = []
    for sent in doc.sents:
        if any(kw in sent.text for kw in ['announced', 'launched', 'started', 'reported', 'held']):
            date_match = [ent.text for ent in sent.ents if ent.label_ == 'DATE']
            location_match = [ent.text for ent in sent.ents if ent.label_ == 'GPE']
            events.append({
                'event': sent.text,
                'location': location_match[0] if location_match else None,
                'timestamp': date_match[0] if date_match else article['publishedAt']
            })
    return entities, events

# Function to generate Cypher queries for each article
def generate_cypher_queries_for_article(article, article_id):
    queries = []
    for entity, entity_type in article['entities']:
        if entity_type == 'PERSON':
            queries.append(f"MERGE (e:Q5 {{name: '{entity}'}})")  # Q5 for human
        elif entity_type == 'ORG':
            queries.append(f"MERGE (e:Q43229 {{name: '{entity}'}})")  # Q43229 for organization
        elif entity_type == 'GPE':
            queries.append(f"MERGE (e:Q515 {{name: '{entity}'}})")  # Q515 for location
    for event in article['events']:
        event_text = re.sub(r'[^\w\s]', '', event['event'])
        timestamp = event['timestamp'] if event['timestamp'] else 'NULL'
        location = event['location'] if event['location'] else 'NULL'
        queries.append(f"MERGE (ev:Q1656682 {{description: '{event_text}', timestamp: '{timestamp}'}})\n"
                       f"MERGE (loc:Q515 {{name: '{location}'}})\n"
                       f"MERGE (ev)-[:OCCURRED_AT]->(loc)")
    
    cypher_file_path = os.path.join(GRAPH_DIR, f'article_{article_id}.cypher')
    with open(cypher_file_path, 'w') as f:
        for query in queries:
            f.write(query + '\n')
    return cypher_file_path

# Function to generate Graphviz DOT files for each article
def generate_graphviz_for_article(article, article_id):
    dot_lines = ['digraph G {', 'rankdir=LR;']
    for entity, entity_type in article['entities']:
        dot_lines.append(f'"{entity}" [label="{entity}", shape=circle];')
    for event in article['events']:
        event_text = re.sub(r'[^\w\s]', '', event['event'])
        location = event['location'] if event['location'] else 'Unknown Location'
        dot_lines.append(f'"{event_text}" -> "{location}" [label="OCCURRED_AT"];')
    dot_lines.append('}')
    
    dot_file_path = os.path.join(GRAPH_DIR, f'article_{article_id}.dot')
    with open(dot_file_path, 'w') as f:
        f.write('\n'.join(dot_lines))
    return dot_file_path

# Process each article, generating Cypher and Graphviz files
for article_id, article in enumerate(articles):
    print(f'Processing article {article_id}')
    article['entities'], article['events'] = extract_entities_and_events(article)
    cypher_file = generate_cypher_queries_for_article(article, article_id)
    print(f'Cypher queries saved to {cypher_file}')
    dot_file = generate_graphviz_for_article(article, article_id)
    print(f'Graphviz file saved to {dot_file}')
# Out:
# Current working directory: /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks
# Processing article 0
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_0.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_0.dot
# Processing article 1
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_1.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_1.dot
# Processing article 2
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_2.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_2.dot
# Processing article 3
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_3.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_3.dot
# Processing article 4
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_4.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_4.dot
# Processing article 5
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_5.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_5.dot
# Processing article 6
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_6.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_6.dot
# Processing article 7
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_7.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_7.dot
# Processing article 8
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_8.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_8.dot
# Processing article 9
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_9.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_9.dot
# Processing article 10
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_10.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_10.dot
# Processing article 11
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_11.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_11.dot
# Processing article 12
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_12.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_12.dot
# Processing article 13
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_13.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_13.dot
# Processing article 14
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_14.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_14.dot
# Processing article 15
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_15.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_15.dot
# Processing article 16
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_16.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_16.dot
# Processing article 17
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_17.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_17.dot
# Processing article 18
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_18.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_18.dot
# Processing article 19
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_19.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_19.dot
# Processing article 20
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_20.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_20.dot
# Processing article 21
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_21.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_21.dot
# Processing article 22
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_22.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_22.dot
# Processing article 23
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_23.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_23.dot
# Processing article 24
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_24.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_24.dot
# Processing article 25
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_25.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_25.dot
# Processing article 26
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_26.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_26.dot
# Processing article 27
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_27.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_27.dot
# Processing article 28
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_28.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_28.dot
# Processing article 29
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_29.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_29.dot
# Processing article 30
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_30.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_30.dot
# Processing article 31
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_31.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_31.dot
# Processing article 32
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_32.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_32.dot
# Processing article 33
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_33.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_33.dot
# Processing article 34
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_34.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_34.dot
# Processing article 35
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_35.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_35.dot
# Processing article 36
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_36.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_36.dot
# Processing article 37
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_37.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_37.dot
# Processing article 38
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_38.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_38.dot
# Processing article 39
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_39.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_39.dot
# Processing article 40
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_40.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_40.dot
# Processing article 41
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_41.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_41.dot
# Processing article 42
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_42.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_42.dot
# Processing article 43
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_43.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_43.dot
# Processing article 44
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_44.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_44.dot
# Processing article 45
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_45.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_45.dot
# Processing article 46
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_46.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_46.dot
# Processing article 47
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_47.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_47.dot
# Processing article 48
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_48.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_48.dot
# Processing article 49
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_49.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_49.dot
# Processing article 50
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_50.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_50.dot
# Processing article 51
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_51.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_51.dot
# Processing article 52
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_52.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_52.dot
# Processing article 53
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_53.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_53.dot
# Processing article 54
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_54.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_54.dot
# Processing article 55
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_55.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_55.dot
# Processing article 56
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_56.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_56.dot
# Processing article 57
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_57.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_57.dot
# Processing article 58
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_58.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_58.dot
# Processing article 59
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_59.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_59.dot
# Processing article 60
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_60.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_60.dot
# Processing article 61
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_61.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_61.dot
# Processing article 62
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_62.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_62.dot
# Processing article 63
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_63.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_63.dot
# Processing article 64
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_64.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_64.dot
# Processing article 65
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_65.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_65.dot
# Processing article 66
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_66.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_66.dot
# Processing article 67
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_67.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_67.dot
# Processing article 68
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_68.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_68.dot
# Processing article 69
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_69.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_69.dot
# Processing article 70
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_70.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_70.dot
# Processing article 71
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_71.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_71.dot
# Processing article 72
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_72.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_72.dot
# Processing article 73
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_73.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_73.dot
# Processing article 74
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_74.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_74.dot
# Processing article 75
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_75.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_75.dot
# Processing article 76
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_76.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_76.dot
# Processing article 77
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_77.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_77.dot
# Processing article 78
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_78.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_78.dot
# Processing article 79
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_79.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_79.dot
# Processing article 80
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_80.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_80.dot
# Processing article 81
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_81.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_81.dot
# Processing article 82
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_82.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_82.dot
# Processing article 83
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_83.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_83.dot
# Processing article 84
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_84.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_84.dot
# Processing article 85
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_85.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_85.dot
# Processing article 86
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_86.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_86.dot
# Processing article 87
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_87.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_87.dot
# Processing article 88
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_88.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_88.dot
# Processing article 89
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_89.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_89.dot
# Processing article 90
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_90.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_90.dot
# Processing article 91
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_91.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_91.dot
# Processing article 92
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_92.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_92.dot
# Processing article 93
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_93.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_93.dot
# Processing article 94
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_94.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_94.dot
# Processing article 95
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_95.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_95.dot
# Processing article 96
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_96.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_96.dot
# Processing article 97
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_97.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_97.dot
# Processing article 98
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_98.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_98.dot
# Processing article 99
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_99.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_99.dot
# Processing article 100
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_100.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_100.dot
# Processing article 101
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_101.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_101.dot
# Processing article 102
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_102.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_102.dot
# Processing article 103
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_103.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_103.dot
# Processing article 104
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_104.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_104.dot
# Processing article 105
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_105.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_105.dot
# Processing article 106
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_106.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_106.dot
# Processing article 107
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_107.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_107.dot
# Processing article 108
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_108.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_108.dot
# Processing article 109
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_109.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_109.dot
# Processing article 110
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_110.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_110.dot
# Processing article 111
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_111.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_111.dot
# Processing article 112
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_112.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_112.dot
# Processing article 113
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_113.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_113.dot
# Processing article 114
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_114.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_114.dot
# Processing article 115
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_115.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_115.dot
# Processing article 116
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_116.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_116.dot
# Processing article 117
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_117.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_117.dot
# Processing article 118
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_118.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_118.dot
# Processing article 119
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_119.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_119.dot
# Processing article 120
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_120.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_120.dot
# Processing article 121
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_121.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_121.dot
# Processing article 122
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_122.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_122.dot
# Processing article 123
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_123.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_123.dot
# Processing article 124
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_124.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_124.dot
# Processing article 125
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_125.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_125.dot
# Processing article 126
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_126.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_126.dot
# Processing article 127
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_127.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_127.dot
# Processing article 128
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_128.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_128.dot
# Processing article 129
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_129.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_129.dot
# Processing article 130
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_130.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_130.dot
# Processing article 131
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_131.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_131.dot
# Processing article 132
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_132.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_132.dot
# Processing article 133
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_133.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_133.dot
# Processing article 134
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_134.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_134.dot
# Processing article 135
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_135.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_135.dot
# Processing article 136
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_136.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_136.dot
# Processing article 137
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_137.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_137.dot
# Processing article 138
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_138.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_138.dot
# Processing article 139
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_139.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_139.dot
# Processing article 140
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_140.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_140.dot
# Processing article 141
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_141.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_141.dot
# Processing article 142
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_142.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_142.dot
# Processing article 143
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_143.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_143.dot
# Processing article 144
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_144.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_144.dot
# Processing article 145
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_145.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_145.dot
# Processing article 146
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_146.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_146.dot
# Processing article 147
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_147.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_147.dot
# Processing article 148
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_148.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_148.dot
# Processing article 149
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_149.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_149.dot
# Processing article 150
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_150.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_150.dot
# Processing article 151
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_151.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_151.dot
# Processing article 152
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_152.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_152.dot
# Processing article 153
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_153.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_153.dot
# Processing article 154
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_154.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_154.dot
# Processing article 155
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_155.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_155.dot
# Processing article 156
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_156.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_156.dot
# Processing article 157
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_157.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_157.dot
# Processing article 158
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_158.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_158.dot
# Processing article 159
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_159.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_159.dot
# Processing article 160
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_160.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_160.dot
# Processing article 161
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_161.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_161.dot
# Processing article 162
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_162.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_162.dot
# Processing article 163
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_163.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_163.dot
# Processing article 164
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_164.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_164.dot
# Processing article 165
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_165.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_165.dot
# Processing article 166
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_166.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_166.dot
# Processing article 167
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_167.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_167.dot
# Processing article 168
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_168.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_168.dot
# Processing article 169
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_169.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_169.dot
# Processing article 170
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_170.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_170.dot
# Processing article 171
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_171.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_171.dot
# Processing article 172
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_172.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_172.dot
# Processing article 173
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_173.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_173.dot
# Processing article 174
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_174.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_174.dot
# Processing article 175
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_175.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_175.dot
# Processing article 176
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_176.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_176.dot
# Processing article 177
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_177.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_177.dot
# Processing article 178
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_178.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_178.dot
# Processing article 179
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_179.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_179.dot
# Processing article 180
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_180.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_180.dot
# Processing article 181
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_181.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_181.dot
# Processing article 182
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_182.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_182.dot
# Processing article 183
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_183.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_183.dot
# Processing article 184
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_184.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_184.dot
# Processing article 185
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_185.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_185.dot
# Processing article 186
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_186.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_186.dot
# Processing article 187
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_187.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_187.dot
# Processing article 188
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_188.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_188.dot
# Processing article 189
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_189.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_189.dot
# Processing article 190
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_190.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_190.dot
# Processing article 191
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_191.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_191.dot
# Processing article 192
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_192.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_192.dot
# Processing article 193
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_193.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_193.dot
# Processing article 194
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_194.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_194.dot
# Processing article 195
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_195.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_195.dot
# Processing article 196
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_196.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_196.dot
# Processing article 197
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_197.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_197.dot
# Processing article 198
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_198.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_198.dot
# Processing article 199
# Cypher queries saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_199.cypher
# Graphviz file saved to /Users/michaeloboyle/Documents/GitHub/scrantenna/notebooks/data/graph/article_199.dot
